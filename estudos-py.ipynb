# %% [markdown]
# <a href="https://colab.research.google.com/github/Xaviend/estudos-py/blob/main/estudos-py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importar as bibliotecas , sklearn para criar os modelos de regressão e yellowbrick para a visualização de residuals
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from yellowbrick.regressor import ResidualsPlot

# %%
# X = 1 Cria uma variavel do tipo int
# y = 3.3 cria variavel do tipo float
# z = "python" ou 'python' Cria variavel string
# y = false e w = true variáveis tipo logicas
x=1
y=3.3
z="python"
y=False
w=True
